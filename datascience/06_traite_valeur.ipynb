# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# ### Vérifier si les collonnes contient des valeur nulles ?

# %%
df.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
df.notnull()
# Out:
#        id  date  first_name  last_name  email  gender  ip_address  country  \
# 0    True  True        True       True   True    True        True     True
# 1    True  True        True       True   True    True        True     True
# 2    True  True        True       True   True    True        True     True
# 3    True  True        True       True   True    True        True     True
# 4    True  True        True       True   True    True        True     True
# ..    ...   ...         ...        ...    ...     ...         ...      ...
# 995  True  True        True       True   True    True        True     True
# 996  True  True        True       True   True    True        True    False
# 997  True  True        True       True   True    True        True     True
# 998  True  True        True       True   True    True        True     True
# 999  True  True        True       True   True   False        True     True
#
#      price_paid    tax
# 0          True  False
# ...

# %% [markdown]
# ### Filtrer les taxes non nulles

# %%
df[df["tax"].notnull()]
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %% [markdown]
# ### Remplire toutes les colonnes de tax où la valeur n'est pas renseignée

# %%
df["tax"].fillna(0)
# Out:
# 0       0.0
# 1       0.0
# 2      20.0
# 3      20.0
# 4      20.0
#        ...
# 995     0.0
# 996    20.0
# 997    20.0
# 998     0.0
# 999    20.0
# Name: tax, Length: 1000, dtype: float64

# %%
### df["tax"].fillna(method='bfill')

# %% [markdown]
# ### Enlever toute les lignes qui contiennent de valeurs nulles

# %%
df.dropna()
# Out:
#       id        date first_name   last_name                       email  \
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 990  991  03/19/2021       Shep    Thorburn  sthorburnri@prnewswire.com
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.dropna().tail(10)
# Out:
#       id        date first_name last_name                       email  gender  \
# 980  981  03/21/2021       Cari     Henze         chenzer8@toplist.cz    Male
# 982  983  03/07/2021      Aaren   Yesinin    ayesininra@parallels.com  Female
# 983  984  03/03/2021    Rhianon   McGrale          rmcgralerb@wix.com    Male
# 986  987  03/05/2021      Dukey   Espinal  despinalre@accuweather.com    Male
# 987  988  03/13/2021    Patrice      Barr           pbarrrf@google.de    Male
# 988  989  03/07/2021       Yves    Botler  ybotlerrg@miitbeian.gov.cn  Female
# 990  991  03/19/2021       Shep  Thorburn  sthorburnri@prnewswire.com    Male
# 991  992  03/07/2021      Elihu     Crush       ecrushrj@berkeley.edu    Male
# 994  995  03/17/2021   Carolyne  Bruntjen   cbruntjenrm@reference.com  Female
# 997  998  03/13/2021      Betty  Stickels  bstickelsrp@cloudflare.com    Male
#
#          ip_address        country price_paid   tax
# 980   24.235.87.125         France      $7.80  20.0
# ...

# %%
df.dropna().head(10)
# Out:
#     id        date first_name   last_name                       email  gender  \
# 2    3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 3    4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 4    5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# 7    8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov    Male
# 8    9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com    Male
# 11  12  03/16/2021     Bailie       Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn  Female
# 14  15  03/21/2021     Oralie      Maryon             omaryone@va.gov  Female
# 15  16  03/24/2021     Julina       Faint        jfaintf@amazon.co.jp  Female
# 16  17  03/27/2021        Eve     Allaway        eallawayg@ebay.co.uk  Female
#
#          ip_address        country price_paid   tax
# 2     213.8.101.145  United States      $3.73  20.0
# ...

# %%
df.dropna().loc[20:50]
# Out:
#     id        date first_name      last_name                        email  \
# 20  21  03/12/2021    Jeffrey        Stanman        jstanmank@latimes.com
# 21  22  03/05/2021     Mendie           Ayer       mayerl@squarespace.com
# 22  23  03/03/2021     Muriel         Pexton            mpextonm@bing.com
# 27  28  03/25/2021    Staford         London          slondonr@sphinn.com
# 29  30  03/02/2021        Edi          Petru           epetrut@census.gov
# 30  31  03/28/2021      Tommi      Ditchburn        tditchburnu@bbc.co.uk
# 31  32  03/10/2021    Jillene          Baudi          jbaudiv@gizmodo.com
# 32  33  03/29/2021    Eadmund        Laurent      elaurentw@economist.com
# 33  34  03/20/2021        Cam  Francescoccio       cfrancescocciox@si.edu
# 34  35  03/02/2021    Trescha       McCudden       tmccuddeny@nbcnews.com
# 35  36  03/11/2021   Charmian      Greenleaf      cgreenleafz@tinypic.com
# 36  37  03/08/2021      Daisy          Jobey             djobey10@ovh.net
# ...

# %%
df.dropna().shape
# Out:
# (588, 10)

# %% [markdown]
# ### Sibler une colonne dont les valeurs ne sont pas nulles

# %%
df.dropna(subset=["tax"], inplace=True)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...
