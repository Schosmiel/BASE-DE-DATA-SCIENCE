# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %% [markdown]
# ### Remplir les valeurs nulles de tax par 0

# %%
df["tax"].fillna(0, inplace=True)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid     object
# tax           float64
# dtype: object

# %% [markdown]
# ### Modifier  le type de la colone price_paid en float comme la colonne tax

# %%
df.price_paid = df.price_paid.apply(lambda x : x.replace("$", ""))
df.price_paid = df.price_paid.astype(float)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
df.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid    float64
# tax           float64
# dtype: object

# %% [markdown]
# ### Ajout d'une colonne

# %%
df["test"]=0

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax  test
# ...

# %% [markdown]
# ### Supprimer la colonne Test par del

# %%
del df["test"]

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %% [markdown]
# ### Créer une colonne price_total

# %% [markdown]
# ### Multiplier le price_paid par la tax dans la colonne price_total

# %%
df["price_total"] = df["price_paid"] * df["tax"]

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax  price_total
# ...

# %%
del df["price_total"]

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
df["price_total"] = df["price_paid"] * (1 - df["tax"] * 100)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax  price_total
# ...

# %%
del df["price_total"]

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
df["price_total"] = df["price_paid"] * (1 - df["tax"] / 100)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax  price_total
# ...

# %% [markdown]
# ### Créer une colonne pour récupérer les code des pays

# %%
countries = {"United States" : "US", "France" : "FR", "Canada" : "CA", "Morocco":"MA"}
df["country_code"] = df["country"].map(countries)

# %%
df.head()
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country  price_paid   tax  price_total country_code
# 0    160.119.8.119         Canada        5.36   0.0        5.360           CA
# 1   210.51.172.132         Canada        8.32   0.0        8.320           CA
# 2    213.8.101.145  United States        3.73  20.0        2.984           US
# 3    5.140.237.101  United States        3.70  20.0        2.960           US
# 4  106.252.162.233        Morocco        9.24  20.0        7.392           MA

# %%
df.head(20)
# Out:
#     id        date first_name   last_name                       email  gender  \
# 0    1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 1    2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 2    3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 3    4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 4    5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# 5    6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu  Female
# 6    7  03/14/2021        Ava     Kencott          akencott6@phoca.cz  Female
# 7    8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov    Male
# 8    9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com    Male
# 9   10  03/23/2021  Guglielma      Gookes       ggookes9@amazon.co.uk    Male
# 10  11  03/11/2021       Lief   Woodcraft   lwoodcrafta@sitemeter.com    Male
# ...

# %%
df.tail()
# Out:
#        id        date first_name last_name                       email  \
# 995   996  03/24/2021       Duff    Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame   Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty  Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito     Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle  Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country  price_paid   tax  price_total  \
# 995  Female  193.84.247.144         France        3.63   0.0        3.630
# 996  Female  188.219.12.109            NaN        4.59  20.0        3.672
# 997    Male    199.80.60.87  United States        7.54  20.0        6.032
# 998    Male     0.183.63.11  United States        5.81   0.0        5.810
# 999     NaN  170.193.249.83         Canada        8.01  20.0        6.408
#
#     country_code
# 995           FR
# 996          NaN
# 997           US
# 998           US
# ...

# %%
df.tail(20)
# Out:
#        id        date first_name     last_name                        email  \
# 980   981  03/21/2021       Cari         Henze          chenzer8@toplist.cz
# 981   982  03/20/2021      Marty          Scad          mscadr9@addthis.com
# 982   983  03/07/2021      Aaren       Yesinin     ayesininra@parallels.com
# 983   984  03/03/2021    Rhianon       McGrale           rmcgralerb@wix.com
# 984   985  03/17/2021    Koressa        Abbado  kabbadorc@printfriendly.com
# 985   986  03/29/2021     Yvonne    Longworthy        ylongworthyrd@163.com
# 986   987  03/05/2021      Dukey       Espinal   despinalre@accuweather.com
# 987   988  03/13/2021    Patrice          Barr            pbarrrf@google.de
# 988   989  03/07/2021       Yves        Botler   ybotlerrg@miitbeian.gov.cn
# 989   990  03/16/2021   Horatius  Van Arsdalen     hvanarsdalenrh@prlog.org
# 990   991  03/19/2021       Shep      Thorburn   sthorburnri@prnewswire.com
# ...

# %%
df.loc[20 : 50]
# Out:
#     id        date  first_name      last_name                         email  \
# 20  21  03/12/2021     Jeffrey        Stanman         jstanmank@latimes.com
# 21  22  03/05/2021      Mendie           Ayer        mayerl@squarespace.com
# 22  23  03/03/2021      Muriel         Pexton             mpextonm@bing.com
# 23  24  03/09/2021     Ermanno          Ghost           eghostn@webnode.com
# 24  25  03/02/2021         Tod        Willets       twilletso@artisteer.com
# 25  26  03/14/2021        Nobe       Stobbart            nstobbartp@php.net
# 26  27  03/27/2021       Elyse       Glaysher     eglaysherq@mayoclinic.com
# 27  28  03/25/2021     Staford         London           slondonr@sphinn.com
# 28  29  03/03/2021  Willabella        Robbins         wrobbinss@tinyurl.com
# 29  30  03/02/2021         Edi          Petru            epetrut@census.gov
# 30  31  03/28/2021       Tommi      Ditchburn         tditchburnu@bbc.co.uk
# ...
